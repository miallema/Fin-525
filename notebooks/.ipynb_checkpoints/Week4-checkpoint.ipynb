# %%
import numpy as np
import pandas as pd
import requests
import io
import zipfile
from io import BytesIO
myurl='https://www.forexite.com/free_forex_quotes/2011/11/011111.zip'
r = requests.get(myurl)
z = zipfile.ZipFile(BytesIO(r.content))
FX=pd.read_csv(z.open(z.namelist()[0]))
#myfile='data/raw/forexite/011111.csv.zip'
#open(myfile, 'wb').write(r.content)

# %%
FX.head()
# Out:
#   <TICKER>  <DTYYYYMMDD>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>
# 0   EURUSD      20111101     100  1.3841  1.3842  1.3841   1.3841
# 1   EURUSD      20111101     200  1.3841  1.3841  1.3840   1.3840
# 2   EURUSD      20111101     300  1.3841  1.3841  1.3835   1.3836
# 3   EURUSD      20111101     400  1.3836  1.3836  1.3836   1.3836
# 4   EURUSD      20111101     500  1.3837  1.3837  1.3833   1.3835

# %%
FX['<TIME>']  = FX['<TIME>'].apply(str).str.zfill(6)
FX['<DATETIME>'] = FX["<DTYYYYMMDD>"].map(str) + FX["<TIME>"].map(str)
FX['<DATETIME>'] = pd.to_datetime(FX['<DATETIME>'],format = '%Y%m%d%H%M%S')
FX = FX.drop(columns = ['<TIME>',"<DTYYYYMMDD>"])
#FX = FX.set_index('<DATETIME>')

# %%
FX.head()
# Out:
#   <TICKER>  <OPEN>  <HIGH>   <LOW>  <CLOSE>          <DATETIME>
# 0   EURUSD  1.3841  1.3842  1.3841   1.3841 2011-11-01 00:01:00
# 1   EURUSD  1.3841  1.3841  1.3840   1.3840 2011-11-01 00:02:00
# 2   EURUSD  1.3841  1.3841  1.3835   1.3836 2011-11-01 00:03:00
# 3   EURUSD  1.3836  1.3836  1.3836   1.3836 2011-11-01 00:04:00
# 4   EURUSD  1.3837  1.3837  1.3833   1.3835 2011-11-01 00:05:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
FX['<TICKER>'].unique()
# Out:
# array(['EURUSD', 'GBPUSD', 'USDCHF', 'USDJPY', 'EURGBP', 'EURCHF',
#        'EURJPY', 'GBPCHF', 'GBPJPY', 'CHFJPY', 'USDCAD', 'EURCAD',
#        'AUDUSD', 'AUDJPY', 'NZDUSD', 'NZDJPY', 'XAUUSD', 'XAGUSD',
#        'USDCZK', 'USDDKK', 'EURRUB', 'USDHUF', 'USDNOK', 'USDPLN',
#        'USDRUB', 'USDSEK', 'USDSGD', 'USDZAR', 'USDHKD', 'USDTRY',
#        'EURHKD', 'EURTRY', 'EURAUD', 'EURNZD', 'EURSGD', 'EURZAR',
#        'XAUEUR', 'XAGEUR', 'GBPCAD', 'GBPAUD', 'GBPNZD', 'AUDCHF',
#        'AUDCAD', 'AUDNZD', 'NZDCHF', 'NZDCAD', 'CADCHF', 'CADJPY'],
#       dtype=object)

# %%
fig = plt.figure(figsize = (20,10))
sns.lineplot(x = '<DATETIME>', y = '<CLOSE>', hue = '<TICKER>', data = FX)

# %%
FX['<CLOSE_NORMALIZED>'] = FX[['<CLOSE>','<TICKER>']].groupby('<TICKER>').transform(lambda x: x/x.iloc[0])
fig = plt.figure(figsize = (20,10))
sns.lineplot(x = '<DATETIME>', y = '<CLOSE_NORMALIZED>', hue = '<TICKER>', data = FX)

# %%
FX['<CLOSE_LOG>'] = FX[['<CLOSE>','<TICKER>']].groupby('<TICKER>').transform(lambda x: np.log(x).diff())
fig = plt.figure(figsize = (20,10))
sns.lineplot(x = '<DATETIME>', y = '<CLOSE_LOG>', hue = '<TICKER>', data = FX)
